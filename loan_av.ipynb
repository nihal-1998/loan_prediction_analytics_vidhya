# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
data = pd.read_csv("train_loan_data.csv")
data
# Out:
#       Loan_ID  Gender Married Dependents     Education Self_Employed  \
# 0    LP001002    Male      No          0      Graduate            No
# 1    LP001003    Male     Yes          1      Graduate            No
# 2    LP001005    Male     Yes          0      Graduate           Yes
# 3    LP001006    Male     Yes          0  Not Graduate            No
# 4    LP001008    Male      No          0      Graduate            No
# 5    LP001011    Male     Yes          2      Graduate           Yes
# 6    LP001013    Male     Yes          0  Not Graduate            No
# 7    LP001014    Male     Yes         3+      Graduate            No
# 8    LP001018    Male     Yes          2      Graduate            No
# 9    LP001020    Male     Yes          1      Graduate            No
# 10   LP001024    Male     Yes          2      Graduate            No
# 11   LP001027    Male     Yes          2      Graduate           NaN
# 12   LP001028    Male     Yes          2      Graduate            No
# ...

# %%
data = pd.read_csv("train_loan_data.csv")
hi = data[['ApplicantIncome']]
y = data[['LoanAmount']]
hii = np.asarray(hi)
yi = np.asarray(y)
data['LoanAmount'].fillna(data['LoanAmount'].mean(),inplace = True)
data['ApplicantIncome'].fillna(data['ApplicantIncome'].mean(),inplace = True)
data['CoapplicantIncome'].fillna(data['CoapplicantIncome'].mean(),inplace = True)
data['Loan_Amount_Term'].fillna(data['Loan_Amount_Term'].mean(),inplace = True)
data['Credit_History'].fillna(data['Credit_History'].mean(),inplace = True)
data.head()


gender = {'Male':1 , 'Female':0 ,'146':1}
married = {'Yes':1 , 'No':0 , '146':1}
loan_s = {'Y':1 , 'N':0 }
education = {'Graduate':1 , 'Not Graduate':0}
self_emp = {'Yes':1 , 'No':0 , '146':0}
area = {'Rural':1 , 'Semiurban':2 , 'Urban':3}
depen = {'0':0 , '1':1 , '2':2 ,'3+':5,'146':1}
loan_s = {'Y':1 , 'N':0 }
data11=data.fillna('146')

data11['Gender'] = [gender[item] for item in data11['Gender']] 
data11['Married'] = [married[item] for item in data11['Married']] 
data11['Education'] = [education[item] for item in data11['Education']] 
data11['Self_Employed'] = [self_emp[item] for item in data11['Self_Employed']] 
data11['Property_Area'] = [area[item] for item in data11['Property_Area']] 
data11['Loan_Status'] = [loan_s[item] for item in data11['Loan_Status']]
data11['Dependents'] = [depen[item] for item in data11['Dependents']]
 
g = data11['Gender'],data11['Married']
m = data11['Married']
d = data11['Dependents']
e = data11['Education']
s = data11['Self_Employed']
a = data11['ApplicantIncome']
c = data11['CoapplicantIncome']
lo = data11['LoanAmount']
la = data11['Loan_Amount_Term']
ch = data11['Credit_History']
p = data11['Property_Area']
data11.head()
X = data11.drop(columns = ['Loan_ID','Loan_Status'])
y = data11.drop(columns = ['Gender','Loan_ID','Married','Dependents','Education','Self_Employed','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History','Property_Area'])
from sklearn.cross_validation import train_test_split
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=101)


data_test = pd.read_csv("test_loan_data.csv")
data_test.head()
data_test['LoanAmount'].fillna(data_test['LoanAmount'].mean(),inplace = True)
data_test['ApplicantIncome'].fillna(data_test['ApplicantIncome'].mean(),inplace = True)
data_test['CoapplicantIncome'].fillna(data_test['CoapplicantIncome'].mean(),inplace = True)
data_test['Loan_Amount_Term'].fillna(data_test['Loan_Amount_Term'].mean(),inplace = True)
data_test['Credit_History'].fillna(data_test['Credit_History'].mean(),inplace = True)
data_test.head()


gender = {'Male':1 , 'Female':0 ,'146':1}
married = {'Yes':1 , 'No':0 , '146':1}
loan_s = {'Y':1 , 'N':0 }
education = {'Graduate':1 , 'Not Graduate':0}
self_emp = {'Yes':1 , 'No':0 , '146':0}
area = {'Rural':1 , 'Semiurban':2 , 'Urban':3}
depen = {'0':0 , '1':1 , '2':2 ,'3+':5,'146':1}
data_test = data_test.fillna('146')



data_test['Gender'] = [gender[item] for item in data_test['Gender']] 
data_test['Married'] = [married[item] for item in data_test['Married']] 
data_test['Education'] = [education[item] for item in data_test['Education']] 
data_test['Self_Employed'] = [self_emp[item] for item in data_test['Self_Employed']] 
data_test['Property_Area'] = [area[item] for item in data_test['Property_Area']] 
#data11['Loan_Status'] = [loan_s[item] for item in data11['Loan_Status']]
data_test['Dependents'] = [depen[item] for item in data_test['Dependents']]

X_t = data_test.drop(columns = ['Loan_ID'])
#y_t = data11.drop(columns = ['Gender','Loan_ID','Married','Dependents','Education','Self_Employed','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History','Property_Area'])
X_t = np.asarray(X_t)

from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,VotingClassifier,BaggingClassifier,GradientBoostingClassifier
from sklearn.tree import DecisionTreeClassifier
from xgboost import XGBClassifier
from sklearn.naive_bayes import GaussianNB
gn = GaussianNB()
gb = GradientBoostingClassifier()
lr = LogisticRegression(class_weight='balanced',warm_start = 'bool')
tr = DecisionTreeClassifier(max_depth = 5)
rf =RandomForestClassifier(n_estimators = 10)
bg = BaggingClassifier(DecisionTreeClassifier(max_depth = 5),max_samples = 0.2,max_features = 1.0, n_estimators = 13)
vr = VotingClassifier(estimators = [('lr',lr),('tr',tr),('rf',rf)],voting = 'hard')
X_train = np.asarray(X)
#X_test = np.asarray(X_test)
y_train = np.asarray(y)
#y_test = np.asarray(y_test)

rf.fit(X_train,y_train)
predict = rf.predict(X_t)
final = data_test.drop(columns = ['Gender','Married','Dependents','Education','Self_Employed','ApplicantIncome','CoapplicantIncome','LoanAmount','Loan_Amount_Term','Credit_History','Property_Area'])
c = ['Loan_Status']
pa = pd.DataFrame(predict,columns=c)
loan_st = {1:'Y' , 0:'N' }

pa['Loan_Status'] = [loan_st[item] for item in pa['Loan_Status']] 
pa
final_loan = pd.merge(final,pa[['Loan_Status']], left_index=True, right_index=True)
final_loan
from pandas import ExcelWriter

writer = ExcelWriter('final_rf_10.xlsx')
final_loan.to_excel(writer)
writer.save()
# Out:
# C:\Users\Nihal Patel\Anaconda3\lib\site-packages\ipykernel\__main__.py:100: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
plt.scatter(hii,yi)

# %%
data_test = pd.read_csv("test_loan_data.csv")
data_test.head()
data_test['LoanAmount'].fillna(data_test['LoanAmount'].mean(),inplace = True)
data_test['ApplicantIncome'].fillna(data_test['ApplicantIncome'].mean(),inplace = True)
data_test['CoapplicantIncome'].fillna(data_test['CoapplicantIncome'].mean(),inplace = True)
data_test['Loan_Amount_Term'].fillna(data_test['Loan_Amount_Term'].mean(),inplace = True)
data_test['Credit_History'].fillna(data_test['Credit_History'].mean(),inplace = True)
data_test.head()
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.tree import DecisionTreeClassifier
data__1 = data_test.fillna('146')
data__1.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-34-26841214e094> in <module>()
#      21 depen = {'0':0 , '1':1 , '2':2 ,'3+':5,'146':1}
#      22
# ---> 23 data['Gender'] = [gender[item] for item in data['Gender']]
#      24 data['Married'] = [married[item] for item in data['Married']]
#      25 data['Education'] = [education[item] for item in data['Education']]
#
# <ipython-input-34-26841214e094> in <listcomp>(.0)
#      21 depen = {'0':0 , '1':1 , '2':2 ,'3+':5,'146':1}
#      22
# ---> 23 data['Gender'] = [gender[item] for item in data['Gender']]
#      24 data['Married'] = [married[item] for item in data['Married']]
#      25 data['Education'] = [education[item] for item in data['Education']]
#
# KeyError: nan

# %%
gender = {'Male':1 , 'Female':0 ,'146':1}
married = {'Yes':1 , 'No':0 , '146':1}
loan_s = {'Y':1 , 'N':0 }
education = {'Graduate':1 , 'Not Graduate':0}
self_emp = {'Yes':1 , 'No':0 , '146':0}
area = {'Rural':1 , 'Semiurban':2 , 'Urban':3}
depen = {'0':0 , '1':1 , '2':2 ,'3+':5,'146':1}
#data_1 = data.fillna('q')

# %%
data__1['Gender'] = [gender[item] for item in data__1['Gender']]

# %%
data__1['Married'] = [married[item] for item in data__1['Married']]

# %%
data__1['Education'] = [education[item] for item in data__1['Education']]

# %%
data__1['Self_Employed'] = [self_emp[item] for item in data__1['Self_Employed']]

# %%
data__1['Property_Area'] = [area[item] for item in data__1['Property_Area']] 
data__1.head()
# Out:
#     Loan_ID  Gender  Married Dependents  Education  Self_Employed  \
# 0  LP001015       1        1          0          1              0
# 1  LP001022       1        1          1          1              0
# 2  LP001031       1        1          2          1              0
# 3  LP001035       1        1          2          1              0
# 4  LP001051       1        0          0          0              0
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History  Property_Area
# 0        1.000000              3
# 1        1.000000              3
# 2        1.000000              3
# ...

# %%
#data__1['Dependents'] = [depen[item] for item in data__1['Dependents']] 
#data__1['Loan_Status'] = [loan_s[item] for item in data__1['Loan_Status']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-22-dbac104027d5> in <module>()
# ----> 1 data__1['Dependents'] = [depen[item] for item in data__1['Dependents']]
#       2 #data__1['Loan_Status'] = [loan_s[item] for item in data__1['Loan_Status']]
#
# <ipython-input-22-dbac104027d5> in <listcomp>(.0)
# ----> 1 data__1['Dependents'] = [depen[item] for item in data__1['Dependents']]
#       2 #data__1['Loan_Status'] = [loan_s[item] for item in data__1['Loan_Status']]
#
# KeyError: 0

# %%
X = data_1[['Dependents','Education','Self_Employed','ApplicantIncome','CoapplicantIncome','LoanAmount','Property_Area']]

# %%
y = data_1[['Loan_Status']]

# %%
import sklearn
from sklearn.cross_validation import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=101)

# %%
from sklearn import tree

# %%
clf = tree.DecisionTreeClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-119-b24cd2b9d3e0> in <module>()
# ----> 1 clf.fit(X_train,y_train)
#
# C:\Users\Nihal Patel\Anaconda3\lib\site-packages\sklearn\tree\tree.py in fit(self, X, y, sample_weight, check_input, X_idx_sorted)
#     317         if not isinstance(criterion, Criterion):
#     318             if is_classification:
# --> 319                 criterion = CRITERIA_CLF[self.criterion](self.n_outputs_,
#     320                                                          self.n_classes_)
#     321             else:
#
# KeyError: '5'
